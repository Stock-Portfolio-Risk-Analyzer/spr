# %%
from datautils import quandl_info as gd
from datetime import datetime as dt
from IPython.display import display
import pandas as pd
import numpy as np

# %% [markdown]
# ## Get daily stock data between dates

# %%
start_date = dt(year=2015, month=1, day=1)
end_date = dt(year=2015, month=12, day=31)

data = gd.get_stock_data('GOOG', start_date, end_date)
display(data.head(10))
# Out:
#               Open     High      Low   Close   Volume  Ex-Dividend  \
# Date
# 2015-01-02  529.01  531.270  524.100  524.81  1443471            0
# 2015-01-05  523.26  524.330  513.060  513.87  2032052            0
# 2015-01-06  515.00  516.175  501.050  501.96  2879847            0
# 2015-01-08  498.30  503.480  491.000  502.68  3340321            0
# 2015-01-12  494.94  495.976  487.560  492.55  2314624            0
# 2015-01-13  498.90  502.980  492.390  496.18  2362493            0
# 2015-01-14  494.65  503.230  493.000  500.87  2207198            0
# 2015-01-15  505.57  505.680  497.760  501.79  2707763            0
# 2015-01-20  510.62  512.500  506.016  506.90  2221783            0
# 2015-01-21  507.25  519.280  506.200  518.04  2245594            0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2015-01-02            1     529.01    531.270   524.100      524.81
# 2015-01-05            1     523.26    524.330   513.060      513.87
# ...

# %% [markdown]
# ## Get multiple stock data

# %%
start_date = dt(year=2015, month=1, day=1)
end_date = dt(year=2015, month=12, day=31)

data = gd.get_stock_data_multiple(["GOOG", "AAPL"], start_date, end_date)
display(data["GOOG"].head(10))
display(data["AAPL"].head(10))
# Out:
#               Open     High      Low   Close   Volume  Ex-Dividend  \
# Date
# 2015-01-02  529.01  531.270  524.100  524.81  1443471            0
# 2015-01-05  523.26  524.330  513.060  513.87  2032052            0
# 2015-01-06  515.00  516.175  501.050  501.96  2879847            0
# 2015-01-08  498.30  503.480  491.000  502.68  3340321            0
# 2015-01-12  494.94  495.976  487.560  492.55  2314624            0
# 2015-01-13  498.90  502.980  492.390  496.18  2362493            0
# 2015-01-14  494.65  503.230  493.000  500.87  2207198            0
# 2015-01-15  505.57  505.680  497.760  501.79  2707763            0
# 2015-01-20  510.62  512.500  506.016  506.90  2221783            0
# 2015-01-21  507.25  519.280  506.200  518.04  2245594            0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2015-01-02            1     529.01    531.270   524.100      524.81
# 2015-01-05            1     523.26    524.330   513.060      513.87
# ...

# %% [markdown]
# ## Get percentage returns

# %%
start_date = dt(year=2015, month=1, day=1)
end_date = dt(year=2015, month=12, day=31)

data = gd.get_pct_returns("GE", start_date, end_date)
display(data.head(10))
# Out:
# Date
# 2015-01-02    0.000000
# 2015-01-05   -0.018356
# 2015-01-06   -0.021545
# 2015-01-08    0.012464
# 2015-01-12   -0.016003
# 2015-01-13   -0.005004
# 2015-01-14   -0.003353
# 2015-01-15   -0.008410
# 2015-01-20    0.011450
# 2015-01-21    0.007966
# Name: Adj. Close, dtype: float64

# %% [markdown]
# ## Use a different Quandl database

# %%
start_date = dt(year=2015, month=1, day=1)
end_date = dt(year=2015, month=12, day=31)

# use Yahoo's stock database
# default is Quandl's WIKI
data = gd.get_stock_data("GOOG", start_date, end_date, "YAHOO")
display(data.head(10))
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-01-02  529.012399  531.272443  524.102327  524.812404  1447600
# 2015-01-05  523.262377  524.332389  513.062315  513.872306  2059800
# 2015-01-06  515.002358  516.177334  501.052266  501.962262  2899900
# 2015-01-07  507.002299  507.246285  499.652247  501.102268  2065100
# 2015-01-08  497.992238  503.482300  491.002212  502.682255  3353600
# 2015-01-09  504.762300  504.922285  494.792239  496.172274  2069400
# 2015-01-12  494.942247  495.978261  487.562205  492.552209  2322400
# 2015-01-13  498.842256  502.982302  492.392254  496.182251  2370500
# 2015-01-14  494.652237  503.232286  493.002234  500.872267  2235700
# 2015-01-15  505.572291  505.682273  497.762267  501.792271  2715800
#
#             Adjusted Close
# Date
# 2015-01-02      524.812404
# 2015-01-05      513.872306
# 2015-01-06      501.962262
# 2015-01-07      501.102268
# 2015-01-08      502.682255
# 2015-01-09      496.172274
# ...
